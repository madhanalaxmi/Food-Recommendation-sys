# %%
import pandas as pd 
import numpy as np
import warnings
import time
import seaborn as sns
import matplotlib.pyplot as plt
import random
import nltk
from nltk.corpus import stopwords

warnings.filterwarnings('ignore')

# %%
class Profile:
    
    df = pd.read_csv('C:\\Users\\SUVARNA\\Food Recommendation\\Data Processing\\dataset.csv') # static variable
    
    def __init__(self,diet,disease,Nutrient,food_type,favorite_food):
        self.diet = diet
        self.disease = disease
        self.nutrient = Nutrient
        self.type = food_type
        self.like = favorite_food
        self.df2 = pd.DataFrame(columns=list(Profile.df.columns))
        self.df3 = pd.DataFrame(columns=list(Profile.df.columns))
        self.df4 = pd.DataFrame(columns=list(Profile.df.columns))
        self.df5 = pd.DataFrame(columns=list(Profile.df.columns))
        self.df6 = pd.DataFrame(columns=list(Profile.df.columns))
        
    def removestop(self,tokens):
        stop = set(stopwords.words('english'))
        file = open("C:\\Users\\SUVARNA\\Downloads\\stopwords.txt",'r')
        l = list(file.read().split())
        stop = list(stop) +l
        l = [token for token in tokens if token not in stop]
        return l
            
    def inputs(self,diet,disease,Nutrient,food_type,favorite_food):
        
        if Nutrient:
            self.df2 = Profile.df[Profile.df.Nutrient.isin(Nutrient)]
            self.df2 = self.df2.reset_index()
       
        if food_type:
            self.df2 = self.df2[self.df2.Veg_Non.isin(food_type)]
            self.df2 = self.df2.reset_index()
      
        if diet:
            for i in range(self.df2.shape[0]):
                l = str(self.df2.loc[i,'Diet']).split()
                
                for d in diet:
                    if d in l:
                        self.df4=self.df4.append(self.df2.loc[i])
 
        if disease:
            for i in range(self.df2.shape[0]):
                l = str(self.df2.loc[i,'Disease']).split()
                for d in disease:
                    if d in l:
                        self.df5=self.df5.append(self.df2.loc[i])

        if favorite_food:
            f = self.removestop(favorite_food.split())
            for i in range(Profile.df.shape[0]):
                n = [j.lower() for j in str(Profile.df.loc[i,'Name']).split()]
                for j in n:
                    for k in f:
                        if k==j:
                            self.df6=self.df6.append(Profile.df.loc[i])
            for i in range(Profile.df.shape[0]):
                n = [j.lower() for j in str(Profile.df.loc[i,'description']).split()]
                for j in n:
                    for k in f:
                        if k==j:
                            self.df6=self.df6.append(df.loc[i])
            for i in range(Profile.df.shape[0]):
                n = [j.lower() for j in str(Profile.df.loc[i,'catagory']).split()]
                for j in n:
                    for k in f:
                        if k==j:
                            self.df6=self.df6.append(Profile.df.loc[i])
            
        return self.df2,self.df3,self.df4,self.df5,self.df6
    
    def get_profile(self):
        df2,df3,df4,df5,df6 = self.inputs(self.diet,self.disease,self.nutrient,self.type,self.like)
        
        df_merge = pd.concat([df2,df3,df4,df5,df6],axis=0).drop_duplicates(subset='Name')
        df_merge = df_merge.filter(['Name','Nutrient','Veg_Non','Price','Review','description'])
        print(df_merge.shape)
        
        return df_merge

# %%
# multiple inputs by radio button
ob = Profile(['high_protien_diet','gluten_free_diet'],['diabeties','anemia'],
             ['calcium','protien'],['non-veg','veg'],'i like burger and sandwich')

profile = ob.get_profile()
profile
# Out:
# (48, 6)
#                                                   Name   Nutrient  Veg_Non  \
# 0           japanese curry arancini with  barley salsa    calcium      veg
# 1                                 cream of almond soup    calcium      veg
# 2         lemon honey glazed sous vide corn on the cob    protien  non-veg
# 3              baked namakpara with roasted almond dip    calcium      veg
# 4                    grilled almond barfi (sugar free)    calcium      veg
# 5                                          apple rabdi    calcium      veg
# 6                           green lentil dessert fudge    calcium      veg
# 7                                   cashew nut cookies    protien      veg
# 8                                        almond pearls    protien      veg
# 9                                   baked almond kofta    calcium      veg
# 10                           almond and amaranth ladoo    calcium      veg
# 11                        sweet potato and quinoa bowl    protien      veg
# 12                                        oats khichdi    protien      veg
# 13            almond and chicken momos (without shell)    calcium  non-veg
# 16                              sous-vide salmon tikka    calcium  non-veg
# 17                                       tiny vada pao    calcium      veg
# 20                   caramelized sesame smoked almonds    calcium      veg
# 21                                     tricolour pasta    calcium      veg
# 22                   clotted cottage cheese croquettes    calcium      veg
# 25                        holi special ice tea thandai    calcium      veg
# 26                                     chicken roulade    calcium  non-veg
# 27                               cheese chicken kebabs    calcium  non-veg
# 28                                   mutton pepper fry    protien  non-veg
# 29                     seared salmon in tabasco butter    calcium  non-veg
# 30                              kale channe ki biryani    calcium      veg
# 31                           oats &amp; shallots pulao    protien      veg
# 32                                          corn pulao    protien      veg
# 33                                vegetable bruschetta    calcium      veg
# 34                         cheese and avocado parantha    calcium      veg
# 36              mix fruit laccha rabri tortilla crunch    calcium      veg
# 40                      quinoa coconut crumble custard    protien      veg
# 41                stuffed eggplant with schezwan sauce    protien      veg
# 43   amaranthus granola with lemon yogurt, berries ...    calcium      veg
# 44                           chocolate chip cheesecake    calcium      veg
# 45                                      ginger cookies    protien      veg
# 51                                          rice kheer    calcium      veg
# 54                            christmas dry fruit cake    calcium      veg
# 55                                 cheese and ham roll    calcium      veg
# 57                              orange quinoa sevaiyan    protien      veg
# 63                     arbi kofta with mint yogurt dip    calcium      veg
# 64                                mango and mint kheer    calcium      veg
# 65                           red velvet banana pudding    calcium      veg
# 72                             jalapeno cheese fingers    calcium      veg
# 73                      californian breakfast benedict    protien      veg
# 85                         french onion grilled cheese    calcium      veg
# 86                               pasta in cheese sauce    calcium      veg
# 87                                chicken tikka masala    calcium  non-veg
# 247                    egg and cheddar cheese sandwich  vitamin_a  non-veg
#
#     Price Review                                        description
# 0     680      9  japanese curry, sticky rice, cheese inside ric...
# 1     315      8  vegetable stock, skimmed milk, toasted almonds...
# 2     515      5  young corn on the cob, honey, lemon juice, gar...
# 3     480      5  almonds (crushed), tomato, garlic cloves, basi...
# 4     420      6     khoya, sweetener (optional), almonds (crushed)
# 5     515      2  apples, milk, sugar, green cardamoms, almonds ...
# 6     545      2  whole moong beans, cow ghee, raisins, whole mi...
# 7     445      5  cashew paste, ghee, khaand (a sweetening agent...
# 8     380      1  toasted almonds, blueberries, oats, corn flake...
# 9     360      4  potato (boiled), nutmeg, milk, almonds (crushe...
# 10    440      6  popped amaranth seeds, jaggery, almonds (slive...
# 11    310      3  स्वीट पौटेटो क्यूब्स, नारियल, प्याज, क्निोआ (प...
# 12    320      1  क्विक कुकिंग ओट्स, मूंगदाल, जीरा, हल्दी पाउडर,...
# 13    250     10  chicken mince, garlic, carrots, spring onion, ...
# 16    320      6  norwegian salmon, black garlic pickle, butter,...
# 17    360      5  potatoes (boiled and mashed), garlic, ginger, ...
# 20    435     10  साबुत बादाम, सफेद और काले तिल, चीनी, रोजमेरी, ...
# 21    275      9  penne, fresh broccoli, carrot, green onions, b...
# 22    435      9  black pepper, black salt, bread crumb, corn fl...
# 25    260      4  ground white pepper (kali mirch), assam tea ba...
# 26    635      1  chicken breasts, olives, jalapenos, bell peppe...
# 27    415      5  चिकन थाईज़, लहसुन का पेस्ट, लहसुन का पेस्ट, पी...
# 28    620      9  लैंब करी कट, पैपर पाउडर, रिफाइंड तेल, सौंफ पाउ...
# 29    610      9  butter, tabasco, chives, salt, salmon fillet, ...
# 30    430      6  black gram (kala chana), basmati rice (soaked ...
# 31    330      8  चावल, हरा धनिया, हरी मिर्च, प्याज , दालचीनी, इ...
# 32    595      5  बासमती चावल, अमेरिकन कॉर्न के दाने, जैतून का त...
# 33    415      8  baguette (grilled slices), black olive tapenad...
# 34    215      7  गेंहू का आटा, कसूरी मेथी, पानी, जैतून का तेल, ...
# 36    385      1  milk, sugar, cardamom powder, saffron, almonds...
# 40    500      6  क्निोआ (पका हुआ), ओट्स, दालचीनी पाउडर, नमक, ब्...
# 41    565      1  mixed vegetables, eggplant, cottage cheese, co...
# 43    555     10  popped amaranthus (cholai), oats, almonds, cin...
# 44    615      5  butter biscuits (broken into pieces), butter (...
# 45    350      8  मक्खन, कैस्टर शुगर, बेकिंग पाउडर, बेकिंग सोडा,...
# 51    225      3  milk, rice (washed), sugar, raisins, green car...
# 54    265      4  butter (at room temperature), dark brown sugar...
# 55    360     10  hung curd, butter, cream, ground pimento, lemo...
# 57    420     10  sevaiyan, quinoa, orange juice , dried figs, s...
# 63    200      5  arbi/colocasia roots, water chestnut flour (ku...
# 64    300      4  milk, basmati rice, powdered sugar / sugar sub...
# 65    505      8  one can of sweetened condensed milk, ice cold ...
# 72    245     10  yellow cornmeal, sugar, baking soda, salt, but...
# 73    645      4  brioche loaf, avocado paste, eggs, tomato, spi...
# 85    660      4     ब्राउचे स्लाइस ब्रेड, प्याज, तेल , एमैंटल चीज़
# 86    405      7  दूध, मैदा, मक्खन, कालीमिर्च पाउडर, जायफल, चीज़...
# 87    405      7        d in a yogurt tomato sauce. creamy texture.
# 247   255      8        egg, salt, pepper, ham slices, basil leaves
